# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('chennai_reservoir_levels.csv')
df
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# ...          ...     ...         ...       ...              ...
# 5642  13-06-2019    30.0         0.0       0.0              1.0
# 5643  14-06-2019    28.0         0.0       0.0              1.0
# 5644  15-06-2019    27.0         0.0       0.0              1.0
# 5645  16-06-2019    26.0         0.0       0.0              1.0
# 5646  17-06-2019    25.0         0.0       0.0              1.0
#
# [5647 rows x 5 columns]

# %%
#plotly, cufflinks libraries
#tableau / power BI
#SQL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   object
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 220.7+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%d-%m-%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 220.7 KB

# %%
df['Year'] = df['Date'].apply(lambda x:x.year)
df['Month'] = df['Date'].apply(lambda x:x.month)

# %%
df.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year  Month
# 0 2004-01-01     3.9         0.0     268.0              0.0  2004      1
# 1 2004-01-02     3.9         0.0     268.0              0.0  2004      1
# 2 2004-01-03     3.9         0.0     267.0              0.0  2004      1
# 3 2004-01-04     3.9         0.0     267.0              0.0  2004      1
# 4 2004-01-05     3.8         0.0     267.0              0.0  2004      1

# %%
df['Total'] = df[[ 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM']].sum(axis=1)
df.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year  Month  \
# 0 2004-01-01     3.9         0.0     268.0              0.0  2004      1
# 1 2004-01-02     3.9         0.0     268.0              0.0  2004      1
# 2 2004-01-03     3.9         0.0     267.0              0.0  2004      1
# 3 2004-01-04     3.9         0.0     267.0              0.0  2004      1
# 4 2004-01-05     3.8         0.0     267.0              0.0  2004      1
#
#    Total
# 0  271.9
# 1  271.9
# 2  270.9
# 3  270.9
# 4  270.8

# %%
df.groupby('Year', as_index=False).mean()
# Out:
#     Year                Date       POONDI  CHOLAVARAM     REDHILLS  \
# 0   2004 2004-07-01 12:00:00    77.766967   19.060109   220.899180
# 1   2005 2005-07-02 00:00:00   722.680603  147.771781  1468.480712
# 2   2006 2006-07-02 00:00:00  1827.553425  484.947945  2044.356164
# 3   2007 2007-07-02 00:00:00  1794.912329  286.391781  2356.654795
# 4   2008 2008-07-01 12:00:00  1862.338798  545.609290  2445.161202
# 5   2009 2009-07-02 00:00:00  1846.221918  414.882110  1969.731205
# 6   2010 2010-07-02 00:00:00  1651.523288  382.175342  2045.271233
# 7   2011 2011-07-02 00:00:00  2399.068493  499.509589  2573.326027
# 8   2012 2012-07-01 12:00:00  1742.816940  225.934426  1872.218579
# 9   2013 2013-07-02 00:00:00   536.953425  100.049315  1324.109589
# 10  2014 2014-07-02 00:00:00   311.441096   38.917808  1480.350685
# 11  2015 2015-07-02 00:00:00   495.408219  122.278082  1168.942466
# 12  2016 2016-07-01 12:00:00  1115.937158  182.748634  1412.098361
# ...

# %%
Yearwise = df.groupby('Year', as_index=False).mean()
Yearwise = Yearwise[['Year', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM','Total']]
Yearwise
# Out:
#     Year       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0   2004    77.766967   19.060109   220.899180        68.683060   386.409317
# 1   2005   722.680603  147.771781  1468.480712       581.345205  2920.278301
# 2   2006  1827.553425  484.947945  2044.356164      2075.317808  6432.175342
# 3   2007  1794.912329  286.391781  2356.654795      1715.126027  6153.084932
# 4   2008  1862.338798  545.609290  2445.161202      2196.967213  7050.076503
# 5   2009  1846.221918  414.882110  1969.731205      1795.677123  6026.512356
# 6   2010  1651.523288  382.175342  2045.271233      2020.501370  6099.471233
# 7   2011  2399.068493  499.509589  2573.326027      2492.282192  7964.186301
# 8   2012  1742.816940  225.934426  1872.218579      1571.677596  5412.647541
# 9   2013   536.953425  100.049315  1324.109589       988.964384  2950.076712
# 10  2014   311.441096   38.917808  1480.350685       913.715068  2744.424658
# ...

# %%
plt.figure(figsize=(14,8))
sns.barplot(x='Year',y='Total',data=Yearwise)
# Out:
# <Axes: xlabel='Year', ylabel='Total'>

# %%
Yearwise.columns
# Out:
# Index(['Year', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM', 'Total'], dtype='object')

# %%
Yearwise.plot(x='Year',y=['POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], figsize=(14,8))
# Out:
# <Axes: xlabel='Year'>

# %%
## Monthwise variation in the four dams
Monthwise = df.groupby('Month', as_index=False).mean()
Monthwise = Monthwise[['Month', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM','Total']]
Monthwise
# Out:
#     Month       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0       1  1774.628629  453.087702  2049.701613      1760.641129  6038.059073
# 1       2  1621.638053  381.133186  2002.247788      1601.225664  5606.244690
# 2       3  1457.505565  300.006048  1950.056452      1507.070565  5214.638629
# 3       4  1204.701667  202.635417  1763.093958      1354.150000  4524.581042
# 4       5   947.485887  148.365927  1488.105444      1245.379032  3829.336290
# 5       6   719.382441  101.877944  1322.688223      1134.689507  3278.638116
# 6       7   533.537419   90.434409  1179.418495      1017.574194  2820.964516
# 7       8   479.559570   75.539785  1068.748387       923.808602  2547.656344
# 8       9   665.000956   83.397778  1046.349911       905.124444  2699.873089
# 9      10   891.648473  136.834409  1087.332839       930.800000  3046.615720
# 10     11  1388.374222  390.694756  1685.440800      1531.418800  4995.928578
# ...

# %%
Monthwise.plot(x='Month',y=['POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], figsize=(14,8))
# Out:
# <Axes: xlabel='Month'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
#  5   Year             5647 non-null   int64
#  6   Month            5647 non-null   int64
#  7   Total            5647 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 353.1 KB

# %%
df['Year'] = df['Year'].astype('category')
df['Month'] = df['Month'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
#  5   Year             5647 non-null   category
#  6   Month            5647 non-null   category
#  7   Total            5647 non-null   float64
# dtypes: category(2), datetime64[ns](1), float64(5)
# memory usage: 276.9 KB

# %%
## Water levels in the month of February for the all the years in total water level of the 4 dams

febwise = df[df['Month'] == 2]
febwise.head()
febwise = febwise.groupby('Year', as_index = False).mean()

febwise.plot(x='Year', y = ['POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], figsize = (14, 8))
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Inferences:
#
# * Although chennai receive some rainfall in July-Sep due to SW monsoon but majority of rainfall happens in Oct-Dec
# * From 2006-10  NE monsoon has much more contribution than SW monsoon But trend reversed in last few years, either SW and NE are contributing equally or SW is contributing more than NE.
# * Declining NE monsoon rainfall and thereby water level in four reservoir of Chennai in recent years.
