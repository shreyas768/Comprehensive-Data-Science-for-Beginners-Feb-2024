# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(50)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[48, 96, 11],
#        [33, 94,  4],
#        [70, 70, 22],
#        [ 5,  2, 95]])

# %%
myindex = ['GJ','WB','TN','JK']
mycols = ['Jan','Feb','Mar']

# %%
df1 = pd.DataFrame(data=mydata)

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycols)
df
# Out:
#     Jan  Feb  Mar
# GJ   48   96   11
# WB   33   94    4
# TN   70   70   22
# JK    5    2   95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, GJ to JK
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      int64
#  1   1       4 non-null      int64
#  2   2       4 non-null      int64
# dtypes: int64(3)
# memory usage: 228.0 bytes

# %%
df = pd.read_csv('tips.csv')
df1 = df

# %% [markdown]
# ## Obtaining Basic Information about DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679

# %%
df.sample(8)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2             20.27
# 20        17.92  4.08    Male     No   Sat  Dinner     2              8.96
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 145        8.35  1.50  Female     No  Thur   Lunch     2              4.18
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 15        21.58  3.92    Male     No   Sun  Dinner     2             10.79
#
#          Payer Name         CC Number Payment ID
# 82      Julie Moody      630413282843   Thur4909
# 184     Stephen Cox  3547798222044029    Sun5140
# 20      Thomas Rice  4403296224639756    Sat1709
# 203     Toni Brooks  3582289985920239   Thur7770
# ...

# %%
df.tail(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 238   Kimberly Crane      676184013727    Sat9777
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# ### Selection and Indexing

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
type(df['tip'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##Multiple Columns

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df[['tip', 'sex', 'smoker', 'day']]
# Out:
#       tip     sex smoker   day
# 0    1.01  Female     No   Sun
# 1    1.66    Male     No   Sun
# 2    3.50    Male     No   Sun
# 3    3.31    Male     No   Sun
# 4    3.61  Female     No   Sun
# ..    ...     ...    ...   ...
# 239  5.92    Male     No   Sat
# 240  2.00  Female    Yes   Sat
# 241  2.00    Male    Yes   Sat
# 242  1.75    Male     No   Sat
# 243  3.00  Female     No  Thur
#
# [244 rows x 4 columns]

# %%
df['percentage']=100*df['tip']/df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959    5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608   16.054159
# 2      Travis Walters  6011812112971322    Sun4458   16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260   13.978041
# 4        Tonya Carter  4832732618637221    Sun2251   14.680765

# %%
df['percentage']=df['percentage'].apply(lambda x:round(x,2))

#df['percentage'] = np.round(df['percentage'],3)
#df['percentage'] = df['percentage'].round(2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.94
# 1      Douglas Tucker  4478071379779230    Sun4608       16.05
# 2      Travis Walters  6011812112971322    Sun4458       16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.98
# 4        Tonya Carter  4832732618637221    Sun2251       14.68

# %%
df = df.drop('percentage',axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## Index Basics

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df = df.reset_index()
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0                8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.columns
# Out:
# Index(['Payment ID', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size', 'price_per_person', 'Payer Name', 'CC Number'],
#       dtype='object')

# %%
df = df[[ 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
       'size', 'price_per_person', 'Payer Name', 'CC Number','Payment ID']]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## Grabbing a Row

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df = df.set_index('Payment ID')
df.head(3)
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.iloc[0]  #index_loc
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
#index_name_based
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.iloc[100:116]  #Grabbing Multiple Rows
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Fri4106          11.35  2.50  Female    Yes  Fri  Dinner     2
# Fri8382          15.38  3.00  Female    Yes  Fri  Dinner     2
# Sat6240          44.30  2.50  Female    Yes  Sat  Dinner     3
# Sat1015          22.42  3.48  Female    Yes  Sat  Dinner     2
# Sat3194          20.92  4.08  Female     No  Sat  Dinner     2
# Sat5106          15.36  1.64    Male    Yes  Sat  Dinner     2
# Sat7865          20.49  4.06    Male    Yes  Sat  Dinner     2
# Sat5196          25.21  4.29    Male    Yes  Sat  Dinner     2
# Sat6376          18.24  3.76    Male     No  Sat  Dinner     2
# Sat2614          14.31  4.00  Female    Yes  Sat  Dinner     2
# Sat6801          14.00  3.00    Male     No  Sat  Dinner     2
# Sat4801           7.25  1.00  Female     No  Sat  Dinner     1
# Sun591           38.07  4.00    Male     No  Sun  Dinner     3
# Sun1885          23.95  2.55    Male     No  Sun  Dinner     2
# ...

# %%
df.loc[['Sun2959','Sat2614']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sat2614          14.31  4.00  Female    Yes  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sat2614                 7.16     Amanda Anderson   375638820334211

# %% [markdown]
# #### Removing Row

# %%
#missing values, duplicate rows

# %%
df.head(6)
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# Sun9679                 6.32          Erik Smith   213140353657882

# %%
df.drop('Sun2251',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df.drop(0,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/wl/v3x3g82n3b38s3cvwvtr0r7h0000gn/T/ipykernel_2240/3656403297.py in ?()
# ----> 1 df.drop(0,axis=0)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5254                 weight  250.0   150.0
#    5255         falcon  speed   320.0   250.0
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#    5261             index=index,
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4545         obj = self
#    4546
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# ...

# %%
#df.drop(0,axis=0)  (make sure index is not a named index)

# %% [markdown]
# ## Insert a New Row

# %%
df1.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.94
# 1      Douglas Tucker  4478071379779230    Sun4608       16.05
# 2      Travis Walters  6011812112971322    Sun4458       16.66

# %%
rowone = df1.iloc[2]
rowone
# Out:
# total_bill                     21.01
# tip                              3.5
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                 7.0
# Payer Name            Travis Walters
# CC Number           6011812112971322
# Payment ID                   Sun4458
# percentage                     16.66
# Name: 2, dtype: object

# %%
df1.append(rowone)  #Removed from pandas use below method
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wl/v3x3g82n3b38s3cvwvtr0r7h0000gn/T/ipykernel_2240/777547578.py in ?()
# ----> 1 df1.append(rowone)  #Removed from pandas use below method
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df1.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID  percentage
# 241       Keith Wong  6011891618747196    Sat3880        8.82
# 242     Dennis Dixon     4375220550950      Sat17        9.82
# 243  Michelle Hardin  3511451626698139    Thur672       15.97

# %%
df1.loc[len(df1)] = rowone

# %%
df1.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
# 244       21.01  3.50    Male     No   Sun  Dinner     3              7.00
#
#           Payer Name         CC Number Payment ID  percentage
# 242     Dennis Dixon     4375220550950      Sat17        9.82
# 243  Michelle Hardin  3511451626698139    Thur672       15.97
# 244   Travis Walters  6011812112971322    Sun4458       16.66
